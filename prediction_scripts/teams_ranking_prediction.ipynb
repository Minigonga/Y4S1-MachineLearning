# %% [markdown]
# # Prediction Task: Teams Ranking
#
# In this notebook, we present an approach for predicting team rankings.

# %% [markdown]
# ## Load Dependencies

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import (
    accuracy_score, 
    mean_absolute_error, 
    roc_auc_score,
)
from sklearn.preprocessing import label_binarize

# Used for Regressors
from sklearn.ensemble import (
    RandomForestRegressor, 
    GradientBoostingRegressor, 
    ExtraTreesRegressor
)
from sklearn.linear_model import Ridge

import warnings
warnings.filterwarnings("ignore")
import os

# %% [markdown]
# ## Add Weight to Features
#
# Based on the Spearman correlation analysis conducted in the data preparation notebook, we will assign weights to each feature. Additionally, we will apply temporal weighting to the years as follows: 70% for the previous year, 15% for the year before that, 10% for two years prior, and 5% for the earliest year.

# %%
def add_weighted_history(df, test_year=None):
    df = df.sort_values(["tmID", "year"]).copy()
    
    feature_weights = {
        "made_playoffs":0.33,
        "prev_win_pct": 0.8,
        "prev_coach_win_pct": 0.5,
        "Performance_weighted_2yr": 0.85,
        "OffPerformance_weighted_2yr": 0.6,
        "DefPerformance_weighted_2yr": 1.0,
        "Performance_weighted_3yr": 0.35,
        "OffPerformance_weighted_3yr": 0.25,
        "DefPerformance_weighted_3yr": 0.45,
        "Performance_weighted_4yr": 0.3,
        "OffPerformance_weighted_4yr": 0.2,
        "DefPerformance_weighted_4yr": 0.35
    }

    if test_year is not None:
        df = df[df["year"] <= test_year].copy()

    for feat, importance in feature_weights.items():
        df[f"{feat}_weighted"] = (
            importance * 0.7 * df.groupby("tmID")[feat].shift(1) +
            importance * 0.15 * df.groupby("tmID")[feat].shift(2) +
            importance * 0.1 * df.groupby("tmID")[feat].shift(3) +
            importance * 0.05 * df.groupby("tmID")[feat].shift(4)
        )
    return df

# %% [markdown]
# ## Predict Team Conference Rank
#
# This code defines the `predict_team_conference_rank` function, which predicts team rankings within each conference for a given year.
#
# #### Steps in the Code:
#
# 1. **Load and Prepare Data**
#    - Reads the `teams.csv` dataset.
#    - Applies historical weighting to features using `add_weighted_history`.
#    - Selects relevant features, including historical performance, coaching stats, and multi-year offensive/defensive metrics.
#
# 2. **Split Data into Train and Test Sets**
#    - Training data consists of all rows from `train_years`.
#    - Test data consists of rows from the `test_year`.
#    - Missing feature values in the test set are filled with the corresponding training set mean.
#
# 3. **Model Training and Prediction**
#    Four models are trained and used to predict team scores, which are then converted to ranks within each conference:
#
#    - **Extra Trees Regressor**
#      ```python
#      ExtraTreesRegressor(n_estimators=200, max_depth=4, min_samples_split=2, random_state=42)
#      ```
#      - **n_estimators=200**: Uses 200 trees to reduce variance while keeping training manageable.
#      - **max_depth=4**: Shallow trees prevent overfitting on small datasets.
#      - **min_samples_split=2**: Standard minimum to allow splits.
#      - **Reason**: Ensemble method that reduces variance and performs well on small datasets.
#
#    - **Random Forest Regressor**
#      ```python
#      RandomForestRegressor(n_estimators=200, max_depth=4, min_samples_split=2, max_features='sqrt', random_state=42)
#      ```
#      - **max_features='sqrt'**: Randomly selects a subset of features at each split to reduce correlation between trees.
#      - Other parameters similar to Extra Trees.
#      - **Reason**: Handles non-linear relationships well and generalizes on small datasets.
#
#    - **Gradient Boosting Regressor**
#      ```python
#      GradientBoostingRegressor(n_estimators=200, learning_rate=0.05, max_depth=3, subsample=0.8, random_state=42)
#      ```
#      - **learning_rate=0.05**: Small steps reduce overfitting risk.
#      - **max_depth=3**: Shallow trees prevent overfitting.
#      - **subsample=0.8**: Uses 80% of data per tree to add randomness and reduce variance.
#      - **Reason**: Sequentially corrects previous errors while controlling overfitting.
#
#    - **Ridge Regression**
#      ```python
#      Ridge(alpha=1.0, random_state=42)
#      ```
#      - **alpha=1.0**: L2 regularization to reduce overfitting.
#      - **Reason**: Simple linear model with regularization; serves as a robust baseline.
#
# 4. **Evaluation Metrics**
#    - **MAE (Mean Absolute Error)** – measures average ranking error.
#    - **Accuracy** – proportion of exact rank matches.
#    - **AUC** – calculated using a binarized approach to assess how well the model separates ranks.
#
#
# **Reason for Parameter Choices**:
# - Dataset is small (142 rows), so shallow trees, regularization, and small learning rates prevent overfitting.
# - Ensemble models provide robustness and can handle non-linear relationships, while Ridge regression offers a stable linear baseline.

# %%
def predict_team_conference_rank(test_year):

    df = pd.read_csv("../predict_datasets/teams.csv")
    df = add_weighted_history(df, test_year=test_year)

    feature_cols = [
        "made_playoffs_weighted",
        "prev_win_pct_weighted",                # historical win %
        "prev_coach_win_pct_weighted",          # historical coach performance

        "Performance_weighted_2yr_weighted",    # overall 2-year
        "OffPerformance_weighted_2yr_weighted", # offense 2-year
        "DefPerformance_weighted_2yr_weighted", # defense 2-year

        "Performance_weighted_3yr_weighted",    # overall 3-year
        "OffPerformance_weighted_3yr_weighted", # offense 3-year
        "DefPerformance_weighted_3yr_weighted", # defense 3-year

        "Performance_weighted_4yr_weighted",    # overall 4-year
        "OffPerformance_weighted_4yr_weighted", # offense 4-year
        "DefPerformance_weighted_4yr_weighted"  # defense 4-year
    ]

    target = "rank"

    train_df_base = df[df["year"].isin(list(range(test_year-4, test_year)))]
    test_df_base = df[df["year"] == test_year]

    # Prepare training data
    train_clean_full = train_df_base.dropna(subset=feature_cols + [target])
    train_clean_full = train_clean_full.sort_values(["year", "confID"]).copy()
    
    X_train_full = train_clean_full[feature_cols].values
    y_train_full = train_clean_full[target].values
    
    # Group info for CatBoost
    train_clean_full['group_id'] = train_clean_full.groupby(["year", "confID"]).ngroup()

    # Prepare test data
    test_df_full = test_df_base.copy()
    for col in feature_cols:
        train_mean = train_clean_full[col].mean()
        test_df_full[col].fillna(train_mean, inplace=True)
    
    X_test_full = test_df_full[feature_cols].values
    all_predictions = test_df_full[["year", "confID", "tmID", target]].copy()
    metrics_list = []

    models = {
        "ExtraTrees": ExtraTreesRegressor(n_estimators=200, max_depth=4, min_samples_split=2, random_state=42),
        "RandomForest": RandomForestRegressor(n_estimators=200, max_depth=4, min_samples_split=2, max_features='sqrt', random_state=42),
        "GradientBoosting": GradientBoostingRegressor(n_estimators=200, learning_rate=0.05, max_depth=3, subsample=0.8, random_state=42),
        "Ridge": Ridge(alpha=1.0, random_state=42)
    }

    for name, model in models.items():
        model.fit(X_train_full, y_train_full)

        scores = model.predict(X_test_full)
        test_scores_df = test_df_full.copy()
        test_scores_df['score'] = scores
        
        ascending_rank = name != "CatBoostRanker"
        predicted_ranks = test_scores_df.groupby(["year","confID"])["score"].rank(
            method="first", ascending=ascending_rank
        ).astype(int).values

        all_predictions[f"{name}_Rank"] = predicted_ranks

    # Calculate metrics by conference
    for conf_id in all_predictions["confID"].unique():
        conf_results = all_predictions[all_predictions["confID"] == conf_id].copy()
        if conf_results.empty: continue
        actual = conf_results[target].values
        
        for name in models.keys():
            predicted_ranks = conf_results[f"{name}_Rank"].values
            
            mae = mean_absolute_error(actual, predicted_ranks)
            acc = accuracy_score(actual, predicted_ranks)
            
            try:
                classes = np.unique(np.concatenate([actual, predicted_ranks]))
                
                try:
                    actual_bin = label_binarize(actual, classes=classes)
                    predicted_bin = label_binarize(predicted_ranks, classes=classes)
                    auc = 0.5 if actual_bin.shape[1] == 1 else roc_auc_score(actual_bin, predicted_bin, average='macro', multi_class='ovr')
                except:
                    auc = 0.0
            except:
                auc = 0.0

            metrics_list.append({
                "year": test_year,
                "confID": conf_id,
                "model": name,
                "MAE": mae,
                "Accuracy": acc,
                "AUC": auc
            })

    return all_predictions, pd.DataFrame(metrics_list)

# %% [markdown]
# ## Evaluate Predictions
#
# The `evaluate_predictions` function summarizes and visualizes model performance:
#
# - **Metrics Table:**
#   Aggregates `all_metrics` by `year` and `model`, computing average MAE, Accuracy, and AUC. Adds a rank and displays a styled table with color gradients for easy comparison.
#
# - **Conference Predictions:**
#   For each conference, shows actual and predicted ranks from all models in a styled table, highlighting differences with color gradients.
#
# This allows quick assessment of **which models perform best** overall and how well they predict **team rankings within each conference**.

# %%
from IPython.display import display
import pandas as pd

def evaluate_predictions(all_results, all_metrics):

    avg = (
        all_metrics
        .groupby(["year", "model"])
        .agg(
            Avg_MAE=("MAE", "mean"),
            Avg_Accuracy=("Accuracy", "mean"),
            Avg_AUC=("AUC", "mean"),
        )
        .reset_index()
        .sort_values("Avg_Accuracy", ascending=False)
    )

    df_display = avg.copy()
    df_display.insert(0, "Rank", range(1, len(df_display)+1))

    styled = (
        df_display.style
        .set_table_styles([
            {"selector": "th", "props": [
                ("background-color", "#f5f5dc"), 
                ("color", "black"),
                ("font-weight", "bold"),
                ("border", "1px solid #bdb76b")
            ]},
            {"selector": "td", "props": [
                ("border", "1px solid #dcdcdc")
            ]},
        ])
        .background_gradient(cmap="Blues", subset=["Avg_Accuracy", "Avg_AUC"])
        .background_gradient(cmap="Oranges", subset=["Avg_MAE"])
        .format({"Avg_Accuracy": "{:.2%}", "Avg_MAE": "{:.3f}", "Avg_AUC": "{:.3f}"})
        .set_properties(**{
            "text-align": "center",
            "padding": "6px"
        })
        .hide(axis="index")
    )

    display(styled)

    pred_cols = [c for c in all_results.columns if "_Rank" in c]

    for conf_id in sorted(all_results["confID"].unique()):
        print(f"\nConference {conf_id} Predictions:")

        cdf = (
            all_results[all_results["confID"] == conf_id]
            .sort_values("rank")
            .reset_index(drop=True)
        )

        df_conf = cdf[["year", "tmID", "rank"] + pred_cols]

        styled_conf = (
            df_conf.style
            .set_table_styles([
                {"selector": "th", "props": [
                    ("background-color", "#f5f5dc"),
                    ("color", "black"),
                    ("font-weight", "bold"),
                    ("border", "1px solid #bdb76b")
                ]},
                {"selector": "td", "props": [
                    ("border", "1px solid #d3d3d3")
                ]},
            ])
            .background_gradient(cmap="Blues", subset=pred_cols)
            .set_properties(**{
                "text-align": "center",
                "padding": "6px"
            })
            .hide(axis="index")
        )

        display(styled_conf)

# %% [markdown]
# ### Testing Year 10

# %%
df10, metrics10 = predict_team_conference_rank(10)
evaluate_predictions(df10, metrics10)
# Out:
# <style type="text/css">
# #T_ab2d0 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_ab2d0 td {
#   border: 1px solid #dcdcdc;
# }
# #T_ab2d0_row0_col0, #T_ab2d0_row0_col1, #T_ab2d0_row0_col2, #T_ab2d0_row1_col0, #T_ab2d0_row1_col1, #T_ab2d0_row1_col2, #T_ab2d0_row2_col0, #T_ab2d0_row2_col1, #T_ab2d0_row2_col2, #T_ab2d0_row3_col0, #T_ab2d0_row3_col1, #T_ab2d0_row3_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row0_col3, #T_ab2d0_row1_col3 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row0_col4, #T_ab2d0_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row1_col4 {
#   background-color: #7ab6d9;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row1_col5 {
#   background-color: #7db8da;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row2_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row2_col4 {
#   background-color: #9ac8e0;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row2_col5 {
#   background-color: #a1cbe2;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row3_col3 {
#   background-color: #fd974a;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_ab2d0_row3_col4, #T_ab2d0_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_ab2d0">
#   <thead>
#     <tr>
#       <th id="T_ab2d0_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_ab2d0_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_ab2d0_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_ab2d0_level0_col3" class="col_heading level0 col3" >Avg_MAE</th>
#       <th id="T_ab2d0_level0_col4" class="col_heading level0 col4" >Avg_Accuracy</th>
#       <th id="T_ab2d0_level0_col5" class="col_heading level0 col5" >Avg_AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ab2d0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ab2d0_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_ab2d0_row0_col2" class="data row0 col2" >RandomForest</td>
#       <td id="T_ab2d0_row0_col3" class="data row0 col3" >1.262</td>
#       <td id="T_ab2d0_row0_col4" class="data row0 col4" >39.29%</td>
#       <td id="T_ab2d0_row0_col5" class="data row0 col5" >0.642</td>
#     </tr>
#     <tr>
#       <td id="T_ab2d0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ab2d0_row1_col1" class="data row1 col1" >10</td>
#       <td id="T_ab2d0_row1_col2" class="data row1 col2" >ExtraTrees</td>
#       <td id="T_ab2d0_row1_col3" class="data row1 col3" >1.262</td>
#       <td id="T_ab2d0_row1_col4" class="data row1 col4" >30.95%</td>
#       <td id="T_ab2d0_row1_col5" class="data row1 col5" >0.592</td>
#     </tr>
#     <tr>
#       <td id="T_ab2d0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ab2d0_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_ab2d0_row2_col2" class="data row2 col2" >GradientBoosting</td>
#       <td id="T_ab2d0_row2_col3" class="data row2 col3" >1.571</td>
#       <td id="T_ab2d0_row2_col4" class="data row2 col4" >29.76%</td>
#       <td id="T_ab2d0_row2_col5" class="data row2 col5" >0.583</td>
#     </tr>
#     <tr>
#       <td id="T_ab2d0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ab2d0_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_ab2d0_row3_col2" class="data row3 col2" >Ridge</td>
#       <td id="T_ab2d0_row3_col3" class="data row3 col3" >1.405</td>
#       <td id="T_ab2d0_row3_col4" class="data row3 col4" >23.81%</td>
#       <td id="T_ab2d0_row3_col5" class="data row3 col5" >0.550</td>
#     </tr>
#   </tbody>
# </table>
# Conference 0 Predictions:
# <style type="text/css">
# #T_a3a88 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_a3a88 td {
#   border: 1px solid #d3d3d3;
# }
# #T_a3a88_row0_col0, #T_a3a88_row0_col1, #T_a3a88_row0_col2, #T_a3a88_row1_col0, #T_a3a88_row1_col1, #T_a3a88_row1_col2, #T_a3a88_row2_col0, #T_a3a88_row2_col1, #T_a3a88_row2_col2, #T_a3a88_row3_col0, #T_a3a88_row3_col1, #T_a3a88_row3_col2, #T_a3a88_row4_col0, #T_a3a88_row4_col1, #T_a3a88_row4_col2, #T_a3a88_row5_col0, #T_a3a88_row5_col1, #T_a3a88_row5_col2, #T_a3a88_row6_col0, #T_a3a88_row6_col1, #T_a3a88_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row0_col3, #T_a3a88_row0_col4, #T_a3a88_row0_col5, #T_a3a88_row0_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row1_col3, #T_a3a88_row1_col4, #T_a3a88_row1_col6, #T_a3a88_row4_col5 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row1_col5, #T_a3a88_row2_col3, #T_a3a88_row2_col4, #T_a3a88_row2_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row2_col5, #T_a3a88_row5_col3, #T_a3a88_row5_col4, #T_a3a88_row6_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row3_col3, #T_a3a88_row3_col4, #T_a3a88_row3_col5, #T_a3a88_row3_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row4_col3, #T_a3a88_row4_col4, #T_a3a88_row4_col6, #T_a3a88_row5_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_a3a88_row5_col6, #T_a3a88_row6_col3, #T_a3a88_row6_col4, #T_a3a88_row6_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_a3a88">
#   <thead>
#     <tr>
#       <th id="T_a3a88_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_a3a88_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_a3a88_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_a3a88_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_a3a88_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_a3a88_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_a3a88_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a3a88_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_a3a88_row0_col1" class="data row0 col1" >IND</td>
#       <td id="T_a3a88_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_a3a88_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_a3a88_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_a3a88_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_a3a88_row0_col6" class="data row0 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_a3a88_row1_col1" class="data row1 col1" >ATL</td>
#       <td id="T_a3a88_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_a3a88_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_a3a88_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_a3a88_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_a3a88_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_a3a88_row2_col1" class="data row2 col1" >DET</td>
#       <td id="T_a3a88_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_a3a88_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_a3a88_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_a3a88_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_a3a88_row2_col6" class="data row2 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_a3a88_row3_col1" class="data row3 col1" >WAS</td>
#       <td id="T_a3a88_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_a3a88_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_a3a88_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_a3a88_row3_col5" class="data row3 col5" >6</td>
#       <td id="T_a3a88_row3_col6" class="data row3 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_a3a88_row4_col1" class="data row4 col1" >CHI</td>
#       <td id="T_a3a88_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_a3a88_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_a3a88_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_a3a88_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_a3a88_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_a3a88_row5_col1" class="data row5 col1" >CON</td>
#       <td id="T_a3a88_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_a3a88_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_a3a88_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_a3a88_row5_col5" class="data row5 col5" >4</td>
#       <td id="T_a3a88_row5_col6" class="data row5 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_a3a88_row6_col0" class="data row6 col0" >10</td>
#       <td id="T_a3a88_row6_col1" class="data row6 col1" >NYL</td>
#       <td id="T_a3a88_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_a3a88_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_a3a88_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_a3a88_row6_col5" class="data row6 col5" >7</td>
#       <td id="T_a3a88_row6_col6" class="data row6 col6" >5</td>
#     </tr>
#   </tbody>
# </table>
# Conference 1 Predictions:
# <style type="text/css">
# #T_40084 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_40084 td {
#   border: 1px solid #d3d3d3;
# }
# #T_40084_row0_col0, #T_40084_row0_col1, #T_40084_row0_col2, #T_40084_row1_col0, #T_40084_row1_col1, #T_40084_row1_col2, #T_40084_row2_col0, #T_40084_row2_col1, #T_40084_row2_col2, #T_40084_row3_col0, #T_40084_row3_col1, #T_40084_row3_col2, #T_40084_row4_col0, #T_40084_row4_col1, #T_40084_row4_col2, #T_40084_row5_col0, #T_40084_row5_col1, #T_40084_row5_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row0_col3, #T_40084_row0_col4, #T_40084_row0_col5, #T_40084_row0_col6 {
#   background-color: #1764ab;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row1_col3, #T_40084_row1_col4, #T_40084_row1_col6, #T_40084_row2_col5 {
#   background-color: #d0e1f2;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row1_col5, #T_40084_row2_col4, #T_40084_row5_col3, #T_40084_row5_col6 {
#   background-color: #94c4df;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row2_col3, #T_40084_row2_col6, #T_40084_row5_col4, #T_40084_row5_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row3_col3, #T_40084_row3_col4, #T_40084_row3_col5, #T_40084_row3_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_40084_row4_col3, #T_40084_row4_col4, #T_40084_row4_col5, #T_40084_row4_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_40084">
#   <thead>
#     <tr>
#       <th id="T_40084_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_40084_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_40084_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_40084_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_40084_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_40084_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_40084_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40084_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_40084_row0_col1" class="data row0 col1" >PHO</td>
#       <td id="T_40084_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_40084_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_40084_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_40084_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_40084_row0_col6" class="data row0 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_40084_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_40084_row1_col1" class="data row1 col1" >SEA</td>
#       <td id="T_40084_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_40084_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_40084_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_40084_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_40084_row1_col6" class="data row1 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_40084_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_40084_row2_col1" class="data row2 col1" >LAS</td>
#       <td id="T_40084_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_40084_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_40084_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_40084_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_40084_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_40084_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_40084_row3_col1" class="data row3 col1" >SAS</td>
#       <td id="T_40084_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_40084_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_40084_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_40084_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_40084_row3_col6" class="data row3 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_40084_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_40084_row4_col1" class="data row4 col1" >MIN</td>
#       <td id="T_40084_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_40084_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_40084_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_40084_row4_col5" class="data row4 col5" >6</td>
#       <td id="T_40084_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_40084_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_40084_row5_col1" class="data row5 col1" >SAC</td>
#       <td id="T_40084_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_40084_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_40084_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_40084_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_40084_row5_col6" class="data row5 col6" >3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Testing Year 9

# %%
df9, metrics9 = predict_team_conference_rank(9)
evaluate_predictions(df9, metrics9)
# Out:
# <style type="text/css">
# #T_8ebd1 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_8ebd1 td {
#   border: 1px solid #dcdcdc;
# }
# #T_8ebd1_row0_col0, #T_8ebd1_row0_col1, #T_8ebd1_row0_col2, #T_8ebd1_row1_col0, #T_8ebd1_row1_col1, #T_8ebd1_row1_col2, #T_8ebd1_row2_col0, #T_8ebd1_row2_col1, #T_8ebd1_row2_col2, #T_8ebd1_row3_col0, #T_8ebd1_row3_col1, #T_8ebd1_row3_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_8ebd1_row0_col3, #T_8ebd1_row2_col3 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_8ebd1_row0_col4, #T_8ebd1_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_8ebd1_row1_col3, #T_8ebd1_row3_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_8ebd1_row1_col4, #T_8ebd1_row1_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_8ebd1_row2_col4, #T_8ebd1_row2_col5, #T_8ebd1_row3_col4, #T_8ebd1_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_8ebd1">
#   <thead>
#     <tr>
#       <th id="T_8ebd1_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_8ebd1_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_8ebd1_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_8ebd1_level0_col3" class="col_heading level0 col3" >Avg_MAE</th>
#       <th id="T_8ebd1_level0_col4" class="col_heading level0 col4" >Avg_Accuracy</th>
#       <th id="T_8ebd1_level0_col5" class="col_heading level0 col5" >Avg_AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8ebd1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8ebd1_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_8ebd1_row0_col2" class="data row0 col2" >ExtraTrees</td>
#       <td id="T_8ebd1_row0_col3" class="data row0 col3" >2.000</td>
#       <td id="T_8ebd1_row0_col4" class="data row0 col4" >28.57%</td>
#       <td id="T_8ebd1_row0_col5" class="data row0 col5" >0.583</td>
#     </tr>
#     <tr>
#       <td id="T_8ebd1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_8ebd1_row1_col1" class="data row1 col1" >9</td>
#       <td id="T_8ebd1_row1_col2" class="data row1 col2" >GradientBoosting</td>
#       <td id="T_8ebd1_row1_col3" class="data row1 col3" >2.143</td>
#       <td id="T_8ebd1_row1_col4" class="data row1 col4" >21.43%</td>
#       <td id="T_8ebd1_row1_col5" class="data row1 col5" >0.542</td>
#     </tr>
#     <tr>
#       <td id="T_8ebd1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_8ebd1_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_8ebd1_row2_col2" class="data row2 col2" >RandomForest</td>
#       <td id="T_8ebd1_row2_col3" class="data row2 col3" >2.000</td>
#       <td id="T_8ebd1_row2_col4" class="data row2 col4" >14.29%</td>
#       <td id="T_8ebd1_row2_col5" class="data row2 col5" >0.500</td>
#     </tr>
#     <tr>
#       <td id="T_8ebd1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8ebd1_row3_col1" class="data row3 col1" >9</td>
#       <td id="T_8ebd1_row3_col2" class="data row3 col2" >Ridge</td>
#       <td id="T_8ebd1_row3_col3" class="data row3 col3" >2.143</td>
#       <td id="T_8ebd1_row3_col4" class="data row3 col4" >14.29%</td>
#       <td id="T_8ebd1_row3_col5" class="data row3 col5" >0.500</td>
#     </tr>
#   </tbody>
# </table>
# Conference 0 Predictions:
# <style type="text/css">
# #T_176b3 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_176b3 td {
#   border: 1px solid #d3d3d3;
# }
# #T_176b3_row0_col0, #T_176b3_row0_col1, #T_176b3_row0_col2, #T_176b3_row1_col0, #T_176b3_row1_col1, #T_176b3_row1_col2, #T_176b3_row2_col0, #T_176b3_row2_col1, #T_176b3_row2_col2, #T_176b3_row3_col0, #T_176b3_row3_col1, #T_176b3_row3_col2, #T_176b3_row4_col0, #T_176b3_row4_col1, #T_176b3_row4_col2, #T_176b3_row5_col0, #T_176b3_row5_col1, #T_176b3_row5_col2, #T_176b3_row6_col0, #T_176b3_row6_col1, #T_176b3_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row0_col3, #T_176b3_row3_col4, #T_176b3_row3_col5, #T_176b3_row3_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row0_col4, #T_176b3_row0_col5, #T_176b3_row0_col6, #T_176b3_row3_col3 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row1_col3, #T_176b3_row2_col5, #T_176b3_row4_col4, #T_176b3_row4_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row1_col4, #T_176b3_row1_col6, #T_176b3_row6_col3, #T_176b3_row6_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row1_col5, #T_176b3_row2_col3, #T_176b3_row2_col4, #T_176b3_row2_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row4_col3, #T_176b3_row4_col5, #T_176b3_row6_col4, #T_176b3_row6_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_176b3_row5_col3, #T_176b3_row5_col4, #T_176b3_row5_col5, #T_176b3_row5_col6 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_176b3">
#   <thead>
#     <tr>
#       <th id="T_176b3_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_176b3_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_176b3_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_176b3_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_176b3_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_176b3_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_176b3_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_176b3_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_176b3_row0_col1" class="data row0 col1" >DET</td>
#       <td id="T_176b3_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_176b3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_176b3_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_176b3_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_176b3_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_176b3_row1_col1" class="data row1 col1" >CON</td>
#       <td id="T_176b3_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_176b3_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_176b3_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_176b3_row1_col5" class="data row1 col5" >7</td>
#       <td id="T_176b3_row1_col6" class="data row1 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_176b3_row2_col1" class="data row2 col1" >NYL</td>
#       <td id="T_176b3_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_176b3_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_176b3_row2_col4" class="data row2 col4" >7</td>
#       <td id="T_176b3_row2_col5" class="data row2 col5" >6</td>
#       <td id="T_176b3_row2_col6" class="data row2 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_176b3_row3_col1" class="data row3 col1" >IND</td>
#       <td id="T_176b3_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_176b3_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_176b3_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_176b3_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_176b3_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_176b3_row4_col1" class="data row4 col1" >CHI</td>
#       <td id="T_176b3_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_176b3_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_176b3_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_176b3_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_176b3_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_176b3_row5_col1" class="data row5 col1" >WAS</td>
#       <td id="T_176b3_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_176b3_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_176b3_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_176b3_row5_col5" class="data row5 col5" >3</td>
#       <td id="T_176b3_row5_col6" class="data row5 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_176b3_row6_col0" class="data row6 col0" >9</td>
#       <td id="T_176b3_row6_col1" class="data row6 col1" >ATL</td>
#       <td id="T_176b3_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_176b3_row6_col3" class="data row6 col3" >4</td>
#       <td id="T_176b3_row6_col4" class="data row6 col4" >5</td>
#       <td id="T_176b3_row6_col5" class="data row6 col5" >4</td>
#       <td id="T_176b3_row6_col6" class="data row6 col6" >5</td>
#     </tr>
#   </tbody>
# </table>
# Conference 1 Predictions:
# <style type="text/css">
# #T_b31b2 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_b31b2 td {
#   border: 1px solid #d3d3d3;
# }
# #T_b31b2_row0_col0, #T_b31b2_row0_col1, #T_b31b2_row0_col2, #T_b31b2_row1_col0, #T_b31b2_row1_col1, #T_b31b2_row1_col2, #T_b31b2_row2_col0, #T_b31b2_row2_col1, #T_b31b2_row2_col2, #T_b31b2_row3_col0, #T_b31b2_row3_col1, #T_b31b2_row3_col2, #T_b31b2_row4_col0, #T_b31b2_row4_col1, #T_b31b2_row4_col2, #T_b31b2_row5_col0, #T_b31b2_row5_col1, #T_b31b2_row5_col2, #T_b31b2_row6_col0, #T_b31b2_row6_col1, #T_b31b2_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row0_col3, #T_b31b2_row0_col6, #T_b31b2_row5_col4, #T_b31b2_row5_col5 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row0_col4, #T_b31b2_row2_col5, #T_b31b2_row4_col6, #T_b31b2_row5_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row0_col5, #T_b31b2_row1_col6, #T_b31b2_row4_col3, #T_b31b2_row4_col4 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row1_col3, #T_b31b2_row2_col4, #T_b31b2_row4_col5, #T_b31b2_row5_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row1_col4, #T_b31b2_row1_col5, #T_b31b2_row2_col3, #T_b31b2_row2_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row3_col3, #T_b31b2_row3_col4, #T_b31b2_row3_col5, #T_b31b2_row3_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_b31b2_row6_col3, #T_b31b2_row6_col4, #T_b31b2_row6_col5, #T_b31b2_row6_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_b31b2">
#   <thead>
#     <tr>
#       <th id="T_b31b2_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_b31b2_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_b31b2_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_b31b2_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_b31b2_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_b31b2_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_b31b2_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b31b2_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_b31b2_row0_col1" class="data row0 col1" >SAS</td>
#       <td id="T_b31b2_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_b31b2_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_b31b2_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_b31b2_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_b31b2_row0_col6" class="data row0 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_b31b2_row1_col1" class="data row1 col1" >SEA</td>
#       <td id="T_b31b2_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_b31b2_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_b31b2_row1_col4" class="data row1 col4" >4</td>
#       <td id="T_b31b2_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_b31b2_row1_col6" class="data row1 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_b31b2_row2_col1" class="data row2 col1" >LAS</td>
#       <td id="T_b31b2_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_b31b2_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_b31b2_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_b31b2_row2_col5" class="data row2 col5" >5</td>
#       <td id="T_b31b2_row2_col6" class="data row2 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_b31b2_row3_col1" class="data row3 col1" >SAC</td>
#       <td id="T_b31b2_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_b31b2_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_b31b2_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_b31b2_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_b31b2_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row4_col0" class="data row4 col0" >9</td>
#       <td id="T_b31b2_row4_col1" class="data row4 col1" >HOU</td>
#       <td id="T_b31b2_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_b31b2_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_b31b2_row4_col4" class="data row4 col4" >3</td>
#       <td id="T_b31b2_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_b31b2_row4_col6" class="data row4 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_b31b2_row5_col1" class="data row5 col1" >PHO</td>
#       <td id="T_b31b2_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_b31b2_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_b31b2_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_b31b2_row5_col5" class="data row5 col5" >6</td>
#       <td id="T_b31b2_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_b31b2_row6_col0" class="data row6 col0" >9</td>
#       <td id="T_b31b2_row6_col1" class="data row6 col1" >MIN</td>
#       <td id="T_b31b2_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_b31b2_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_b31b2_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_b31b2_row6_col5" class="data row6 col5" >7</td>
#       <td id="T_b31b2_row6_col6" class="data row6 col6" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Testing Year 8

# %%
df8, metrics8 = predict_team_conference_rank(8)
evaluate_predictions(df8, metrics8)
# Out:
# <style type="text/css">
# #T_44ff4 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_44ff4 td {
#   border: 1px solid #dcdcdc;
# }
# #T_44ff4_row0_col0, #T_44ff4_row0_col1, #T_44ff4_row0_col2, #T_44ff4_row1_col0, #T_44ff4_row1_col1, #T_44ff4_row1_col2, #T_44ff4_row2_col0, #T_44ff4_row2_col1, #T_44ff4_row2_col2, #T_44ff4_row3_col0, #T_44ff4_row3_col1, #T_44ff4_row3_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row0_col3 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row0_col4, #T_44ff4_row0_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row1_col3 {
#   background-color: #fedcbb;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row1_col4 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row1_col5 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row2_col3 {
#   background-color: #fdd7af;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row2_col4 {
#   background-color: #caddf0;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row2_col5 {
#   background-color: #cadef0;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row3_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_44ff4_row3_col4, #T_44ff4_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_44ff4">
#   <thead>
#     <tr>
#       <th id="T_44ff4_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_44ff4_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_44ff4_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_44ff4_level0_col3" class="col_heading level0 col3" >Avg_MAE</th>
#       <th id="T_44ff4_level0_col4" class="col_heading level0 col4" >Avg_Accuracy</th>
#       <th id="T_44ff4_level0_col5" class="col_heading level0 col5" >Avg_AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44ff4_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_44ff4_row0_col1" class="data row0 col1" >8</td>
#       <td id="T_44ff4_row0_col2" class="data row0 col2" >ExtraTrees</td>
#       <td id="T_44ff4_row0_col3" class="data row0 col3" >1.619</td>
#       <td id="T_44ff4_row0_col4" class="data row0 col4" >39.29%</td>
#       <td id="T_44ff4_row0_col5" class="data row0 col5" >0.642</td>
#     </tr>
#     <tr>
#       <td id="T_44ff4_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_44ff4_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_44ff4_row1_col2" class="data row1 col2" >Ridge</td>
#       <td id="T_44ff4_row1_col3" class="data row1 col3" >1.762</td>
#       <td id="T_44ff4_row1_col4" class="data row1 col4" >25.00%</td>
#       <td id="T_44ff4_row1_col5" class="data row1 col5" >0.558</td>
#     </tr>
#     <tr>
#       <td id="T_44ff4_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_44ff4_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_44ff4_row2_col2" class="data row2 col2" >RandomForest</td>
#       <td id="T_44ff4_row2_col3" class="data row2 col3" >1.786</td>
#       <td id="T_44ff4_row2_col4" class="data row2 col4" >15.48%</td>
#       <td id="T_44ff4_row2_col5" class="data row2 col5" >0.500</td>
#     </tr>
#     <tr>
#       <td id="T_44ff4_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_44ff4_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_44ff4_row3_col2" class="data row3 col2" >GradientBoosting</td>
#       <td id="T_44ff4_row3_col3" class="data row3 col3" >2.405</td>
#       <td id="T_44ff4_row3_col4" class="data row3 col4" >8.33%</td>
#       <td id="T_44ff4_row3_col5" class="data row3 col5" >0.458</td>
#     </tr>
#   </tbody>
# </table>
# Conference 0 Predictions:
# <style type="text/css">
# #T_21e85 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_21e85 td {
#   border: 1px solid #d3d3d3;
# }
# #T_21e85_row0_col0, #T_21e85_row0_col1, #T_21e85_row0_col2, #T_21e85_row1_col0, #T_21e85_row1_col1, #T_21e85_row1_col2, #T_21e85_row2_col0, #T_21e85_row2_col1, #T_21e85_row2_col2, #T_21e85_row3_col0, #T_21e85_row3_col1, #T_21e85_row3_col2, #T_21e85_row4_col0, #T_21e85_row4_col1, #T_21e85_row4_col2, #T_21e85_row5_col0, #T_21e85_row5_col1, #T_21e85_row5_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row0_col3, #T_21e85_row0_col6, #T_21e85_row1_col4, #T_21e85_row1_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row0_col4, #T_21e85_row1_col3, #T_21e85_row1_col6, #T_21e85_row4_col5 {
#   background-color: #d0e1f2;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row0_col5, #T_21e85_row4_col3, #T_21e85_row4_col4, #T_21e85_row4_col6 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row2_col3, #T_21e85_row2_col4, #T_21e85_row2_col5, #T_21e85_row2_col6 {
#   background-color: #94c4df;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row3_col3, #T_21e85_row3_col4, #T_21e85_row3_col5, #T_21e85_row3_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_21e85_row5_col3, #T_21e85_row5_col4, #T_21e85_row5_col5, #T_21e85_row5_col6 {
#   background-color: #1764ab;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_21e85">
#   <thead>
#     <tr>
#       <th id="T_21e85_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_21e85_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_21e85_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_21e85_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_21e85_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_21e85_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_21e85_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_21e85_row0_col0" class="data row0 col0" >8</td>
#       <td id="T_21e85_row0_col1" class="data row0 col1" >DET</td>
#       <td id="T_21e85_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_21e85_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_21e85_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_21e85_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_21e85_row0_col6" class="data row0 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_21e85_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_21e85_row1_col1" class="data row1 col1" >IND</td>
#       <td id="T_21e85_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_21e85_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_21e85_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_21e85_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_21e85_row1_col6" class="data row1 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_21e85_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_21e85_row2_col1" class="data row2 col1" >CON</td>
#       <td id="T_21e85_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_21e85_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_21e85_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_21e85_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_21e85_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_21e85_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_21e85_row3_col1" class="data row3 col1" >NYL</td>
#       <td id="T_21e85_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_21e85_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_21e85_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_21e85_row3_col5" class="data row3 col5" >6</td>
#       <td id="T_21e85_row3_col6" class="data row3 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_21e85_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_21e85_row4_col1" class="data row4 col1" >WAS</td>
#       <td id="T_21e85_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_21e85_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_21e85_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_21e85_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_21e85_row4_col6" class="data row4 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_21e85_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_21e85_row5_col1" class="data row5 col1" >CHI</td>
#       <td id="T_21e85_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_21e85_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_21e85_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_21e85_row5_col5" class="data row5 col5" >5</td>
#       <td id="T_21e85_row5_col6" class="data row5 col6" >5</td>
#     </tr>
#   </tbody>
# </table>
# Conference 1 Predictions:
# <style type="text/css">
# #T_52b17 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_52b17 td {
#   border: 1px solid #d3d3d3;
# }
# #T_52b17_row0_col0, #T_52b17_row0_col1, #T_52b17_row0_col2, #T_52b17_row1_col0, #T_52b17_row1_col1, #T_52b17_row1_col2, #T_52b17_row2_col0, #T_52b17_row2_col1, #T_52b17_row2_col2, #T_52b17_row3_col0, #T_52b17_row3_col1, #T_52b17_row3_col2, #T_52b17_row4_col0, #T_52b17_row4_col1, #T_52b17_row4_col2, #T_52b17_row5_col0, #T_52b17_row5_col1, #T_52b17_row5_col2, #T_52b17_row6_col0, #T_52b17_row6_col1, #T_52b17_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row0_col3, #T_52b17_row1_col4, #T_52b17_row5_col5, #T_52b17_row5_col6 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row0_col4, #T_52b17_row0_col5, #T_52b17_row0_col6, #T_52b17_row5_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row1_col3, #T_52b17_row1_col5, #T_52b17_row1_col6, #T_52b17_row5_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row2_col3, #T_52b17_row2_col4, #T_52b17_row3_col6, #T_52b17_row6_col5 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row2_col5, #T_52b17_row6_col3, #T_52b17_row6_col4, #T_52b17_row6_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row2_col6, #T_52b17_row3_col5, #T_52b17_row4_col3, #T_52b17_row4_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_52b17_row3_col3, #T_52b17_row3_col4, #T_52b17_row4_col5, #T_52b17_row4_col6 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_52b17">
#   <thead>
#     <tr>
#       <th id="T_52b17_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_52b17_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_52b17_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_52b17_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_52b17_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_52b17_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_52b17_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52b17_row0_col0" class="data row0 col0" >8</td>
#       <td id="T_52b17_row0_col1" class="data row0 col1" >PHO</td>
#       <td id="T_52b17_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_52b17_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_52b17_row0_col4" class="data row0 col4" >6</td>
#       <td id="T_52b17_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_52b17_row0_col6" class="data row0 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_52b17_row1_col1" class="data row1 col1" >SAS</td>
#       <td id="T_52b17_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_52b17_row1_col3" class="data row1 col3" >7</td>
#       <td id="T_52b17_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_52b17_row1_col5" class="data row1 col5" >7</td>
#       <td id="T_52b17_row1_col6" class="data row1 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_52b17_row2_col1" class="data row2 col1" >SAC</td>
#       <td id="T_52b17_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_52b17_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_52b17_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_52b17_row2_col5" class="data row2 col5" >4</td>
#       <td id="T_52b17_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_52b17_row3_col1" class="data row3 col1" >SEA</td>
#       <td id="T_52b17_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_52b17_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_52b17_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_52b17_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_52b17_row3_col6" class="data row3 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row4_col0" class="data row4 col0" >8</td>
#       <td id="T_52b17_row4_col1" class="data row4 col1" >HOU</td>
#       <td id="T_52b17_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_52b17_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_52b17_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_52b17_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_52b17_row4_col6" class="data row4 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row5_col0" class="data row5 col0" >8</td>
#       <td id="T_52b17_row5_col1" class="data row5 col1" >MIN</td>
#       <td id="T_52b17_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_52b17_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_52b17_row5_col4" class="data row5 col4" >7</td>
#       <td id="T_52b17_row5_col5" class="data row5 col5" >5</td>
#       <td id="T_52b17_row5_col6" class="data row5 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_52b17_row6_col0" class="data row6 col0" >8</td>
#       <td id="T_52b17_row6_col1" class="data row6 col1" >LAS</td>
#       <td id="T_52b17_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_52b17_row6_col3" class="data row6 col3" >4</td>
#       <td id="T_52b17_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_52b17_row6_col5" class="data row6 col5" >3</td>
#       <td id="T_52b17_row6_col6" class="data row6 col6" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Testing Year 7

# %%
df7, metrics7 = predict_team_conference_rank(7)

evaluate_predictions(df7, metrics7)
# Out:
# <style type="text/css">
# #T_3e840 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_3e840 td {
#   border: 1px solid #dcdcdc;
# }
# #T_3e840_row0_col0, #T_3e840_row0_col1, #T_3e840_row0_col2, #T_3e840_row1_col0, #T_3e840_row1_col1, #T_3e840_row1_col2, #T_3e840_row2_col0, #T_3e840_row2_col1, #T_3e840_row2_col2, #T_3e840_row3_col0, #T_3e840_row3_col1, #T_3e840_row3_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row0_col3, #T_3e840_row1_col3 {
#   background-color: #fff5eb;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row0_col4, #T_3e840_row0_col5, #T_3e840_row1_col4, #T_3e840_row1_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row2_col3, #T_3e840_row3_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row2_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row2_col5 {
#   background-color: #6caed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_3e840_row3_col4, #T_3e840_row3_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_3e840">
#   <thead>
#     <tr>
#       <th id="T_3e840_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_3e840_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_3e840_level0_col2" class="col_heading level0 col2" >model</th>
#       <th id="T_3e840_level0_col3" class="col_heading level0 col3" >Avg_MAE</th>
#       <th id="T_3e840_level0_col4" class="col_heading level0 col4" >Avg_Accuracy</th>
#       <th id="T_3e840_level0_col5" class="col_heading level0 col5" >Avg_AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3e840_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3e840_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_3e840_row0_col2" class="data row0 col2" >GradientBoosting</td>
#       <td id="T_3e840_row0_col3" class="data row0 col3" >1.714</td>
#       <td id="T_3e840_row0_col4" class="data row0 col4" >28.57%</td>
#       <td id="T_3e840_row0_col5" class="data row0 col5" >0.583</td>
#     </tr>
#     <tr>
#       <td id="T_3e840_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3e840_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_3e840_row1_col2" class="data row1 col2" >RandomForest</td>
#       <td id="T_3e840_row1_col3" class="data row1 col3" >1.714</td>
#       <td id="T_3e840_row1_col4" class="data row1 col4" >28.57%</td>
#       <td id="T_3e840_row1_col5" class="data row1 col5" >0.583</td>
#     </tr>
#     <tr>
#       <td id="T_3e840_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3e840_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_3e840_row2_col2" class="data row2 col2" >ExtraTrees</td>
#       <td id="T_3e840_row2_col3" class="data row2 col3" >1.857</td>
#       <td id="T_3e840_row2_col4" class="data row2 col4" >21.43%</td>
#       <td id="T_3e840_row2_col5" class="data row2 col5" >0.542</td>
#     </tr>
#     <tr>
#       <td id="T_3e840_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_3e840_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_3e840_row3_col2" class="data row3 col2" >Ridge</td>
#       <td id="T_3e840_row3_col3" class="data row3 col3" >1.857</td>
#       <td id="T_3e840_row3_col4" class="data row3 col4" >14.29%</td>
#       <td id="T_3e840_row3_col5" class="data row3 col5" >0.500</td>
#     </tr>
#   </tbody>
# </table>
# Conference 0 Predictions:
# <style type="text/css">
# #T_e3725 th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_e3725 td {
#   border: 1px solid #d3d3d3;
# }
# #T_e3725_row0_col0, #T_e3725_row0_col1, #T_e3725_row0_col2, #T_e3725_row1_col0, #T_e3725_row1_col1, #T_e3725_row1_col2, #T_e3725_row2_col0, #T_e3725_row2_col1, #T_e3725_row2_col2, #T_e3725_row3_col0, #T_e3725_row3_col1, #T_e3725_row3_col2, #T_e3725_row4_col0, #T_e3725_row4_col1, #T_e3725_row4_col2, #T_e3725_row5_col0, #T_e3725_row5_col1, #T_e3725_row5_col2, #T_e3725_row6_col0, #T_e3725_row6_col1, #T_e3725_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row0_col3, #T_e3725_row0_col4, #T_e3725_row0_col6, #T_e3725_row6_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row0_col5, #T_e3725_row3_col3, #T_e3725_row3_col4, #T_e3725_row3_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row1_col3, #T_e3725_row1_col4, #T_e3725_row2_col6, #T_e3725_row5_col5 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row1_col5, #T_e3725_row1_col6, #T_e3725_row5_col3, #T_e3725_row5_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row2_col3, #T_e3725_row2_col4, #T_e3725_row2_col5, #T_e3725_row5_col6 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row3_col5, #T_e3725_row6_col3, #T_e3725_row6_col4, #T_e3725_row6_col6 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_e3725_row4_col3, #T_e3725_row4_col4, #T_e3725_row4_col5, #T_e3725_row4_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_e3725">
#   <thead>
#     <tr>
#       <th id="T_e3725_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_e3725_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_e3725_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_e3725_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_e3725_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_e3725_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_e3725_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e3725_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_e3725_row0_col1" class="data row0 col1" >CON</td>
#       <td id="T_e3725_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_e3725_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_e3725_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_e3725_row0_col5" class="data row0 col5" >6</td>
#       <td id="T_e3725_row0_col6" class="data row0 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_e3725_row1_col1" class="data row1 col1" >DET</td>
#       <td id="T_e3725_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_e3725_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_e3725_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_e3725_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_e3725_row1_col6" class="data row1 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_e3725_row2_col1" class="data row2 col1" >IND</td>
#       <td id="T_e3725_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_e3725_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_e3725_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_e3725_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_e3725_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_e3725_row3_col1" class="data row3 col1" >WAS</td>
#       <td id="T_e3725_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_e3725_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_e3725_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_e3725_row3_col5" class="data row3 col5" >4</td>
#       <td id="T_e3725_row3_col6" class="data row3 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_e3725_row4_col1" class="data row4 col1" >NYL</td>
#       <td id="T_e3725_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_e3725_row4_col3" class="data row4 col3" >7</td>
#       <td id="T_e3725_row4_col4" class="data row4 col4" >7</td>
#       <td id="T_e3725_row4_col5" class="data row4 col5" >7</td>
#       <td id="T_e3725_row4_col6" class="data row4 col6" >7</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_e3725_row5_col1" class="data row5 col1" >CHA</td>
#       <td id="T_e3725_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_e3725_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_e3725_row5_col4" class="data row5 col4" >2</td>
#       <td id="T_e3725_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_e3725_row5_col6" class="data row5 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_e3725_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_e3725_row6_col1" class="data row6 col1" >CHI</td>
#       <td id="T_e3725_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_e3725_row6_col3" class="data row6 col3" >4</td>
#       <td id="T_e3725_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_e3725_row6_col5" class="data row6 col5" >5</td>
#       <td id="T_e3725_row6_col6" class="data row6 col6" >4</td>
#     </tr>
#   </tbody>
# </table>
# Conference 1 Predictions:
# <style type="text/css">
# #T_1d3ea th {
#   background-color: #f5f5dc;
#   color: black;
#   font-weight: bold;
#   border: 1px solid #bdb76b;
# }
# #T_1d3ea td {
#   border: 1px solid #d3d3d3;
# }
# #T_1d3ea_row0_col0, #T_1d3ea_row0_col1, #T_1d3ea_row0_col2, #T_1d3ea_row1_col0, #T_1d3ea_row1_col1, #T_1d3ea_row1_col2, #T_1d3ea_row2_col0, #T_1d3ea_row2_col1, #T_1d3ea_row2_col2, #T_1d3ea_row3_col0, #T_1d3ea_row3_col1, #T_1d3ea_row3_col2, #T_1d3ea_row4_col0, #T_1d3ea_row4_col1, #T_1d3ea_row4_col2, #T_1d3ea_row5_col0, #T_1d3ea_row5_col1, #T_1d3ea_row5_col2, #T_1d3ea_row6_col0, #T_1d3ea_row6_col1, #T_1d3ea_row6_col2 {
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row0_col3, #T_1d3ea_row0_col5, #T_1d3ea_row0_col6, #T_1d3ea_row2_col4 {
#   background-color: #d6e6f4;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row0_col4, #T_1d3ea_row2_col3, #T_1d3ea_row2_col5, #T_1d3ea_row2_col6 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row1_col3, #T_1d3ea_row1_col4, #T_1d3ea_row3_col6, #T_1d3ea_row5_col5 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row1_col5, #T_1d3ea_row4_col3, #T_1d3ea_row4_col4, #T_1d3ea_row4_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row1_col6, #T_1d3ea_row3_col3, #T_1d3ea_row3_col4, #T_1d3ea_row4_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row3_col5, #T_1d3ea_row5_col3, #T_1d3ea_row5_col4, #T_1d3ea_row5_col6 {
#   background-color: #abd0e6;
#   color: #000000;
#   text-align: center;
#   padding: 6px;
# }
# #T_1d3ea_row6_col3, #T_1d3ea_row6_col4, #T_1d3ea_row6_col5, #T_1d3ea_row6_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 6px;
# }
# </style>
# <table id="T_1d3ea">
#   <thead>
#     <tr>
#       <th id="T_1d3ea_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_1d3ea_level0_col1" class="col_heading level0 col1" >tmID</th>
#       <th id="T_1d3ea_level0_col2" class="col_heading level0 col2" >rank</th>
#       <th id="T_1d3ea_level0_col3" class="col_heading level0 col3" >ExtraTrees_Rank</th>
#       <th id="T_1d3ea_level0_col4" class="col_heading level0 col4" >RandomForest_Rank</th>
#       <th id="T_1d3ea_level0_col5" class="col_heading level0 col5" >GradientBoosting_Rank</th>
#       <th id="T_1d3ea_level0_col6" class="col_heading level0 col6" >Ridge_Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d3ea_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_1d3ea_row0_col1" class="data row0 col1" >LAS</td>
#       <td id="T_1d3ea_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_1d3ea_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_1d3ea_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_1d3ea_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_1d3ea_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_1d3ea_row1_col1" class="data row1 col1" >SAC</td>
#       <td id="T_1d3ea_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_1d3ea_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_1d3ea_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_1d3ea_row1_col5" class="data row1 col5" >6</td>
#       <td id="T_1d3ea_row1_col6" class="data row1 col6" >4</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_1d3ea_row2_col1" class="data row2 col1" >HOU</td>
#       <td id="T_1d3ea_row2_col2" class="data row2 col2" >3.000000</td>
#       <td id="T_1d3ea_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_1d3ea_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_1d3ea_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_1d3ea_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row3_col0" class="data row3 col0" >7</td>
#       <td id="T_1d3ea_row3_col1" class="data row3 col1" >SEA</td>
#       <td id="T_1d3ea_row3_col2" class="data row3 col2" >4.000000</td>
#       <td id="T_1d3ea_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_1d3ea_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_1d3ea_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_1d3ea_row3_col6" class="data row3 col6" >5</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_1d3ea_row4_col1" class="data row4 col1" >PHO</td>
#       <td id="T_1d3ea_row4_col2" class="data row4 col2" >5.000000</td>
#       <td id="T_1d3ea_row4_col3" class="data row4 col3" >6</td>
#       <td id="T_1d3ea_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_1d3ea_row4_col5" class="data row4 col5" >4</td>
#       <td id="T_1d3ea_row4_col6" class="data row4 col6" >6</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_1d3ea_row5_col1" class="data row5 col1" >SAS</td>
#       <td id="T_1d3ea_row5_col2" class="data row5 col2" >6.000000</td>
#       <td id="T_1d3ea_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_1d3ea_row5_col4" class="data row5 col4" >3</td>
#       <td id="T_1d3ea_row5_col5" class="data row5 col5" >5</td>
#       <td id="T_1d3ea_row5_col6" class="data row5 col6" >3</td>
#     </tr>
#     <tr>
#       <td id="T_1d3ea_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_1d3ea_row6_col1" class="data row6 col1" >MIN</td>
#       <td id="T_1d3ea_row6_col2" class="data row6 col2" >7.000000</td>
#       <td id="T_1d3ea_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_1d3ea_row6_col4" class="data row6 col4" >7</td>
#       <td id="T_1d3ea_row6_col5" class="data row6 col5" >7</td>
#       <td id="T_1d3ea_row6_col6" class="data row6 col6" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Overall Performance Assessment
#
# The team ranking prediction models show moderate but inconsistent performance across different years. Overall, the models are able to capture some meaningful patterns in team performance history, as reflected by AUC scores consistently above 0.5, generally in the range of 0.55–0.65. This indicates that the models can discriminate between stronger and weaker teams to some extent.
#
# Performance varies by year and model. For example, RandomForest performed best in Year 10 (39.29% accuracy), ExtraTrees in Years 8 and 9 (28–39%), and GradientBoosting in Year 7 (28.57%). This suggests that no single model is consistently optimal and that the best choice may depend on the characteristics of the specific year's data. The MAE in the best-performing years ranges from about 1.26 to 1.62, meaning predictions are typically off by 1–1.5 ranks on average.
#
# However, exact rank accuracy remains low, between 8% and 39%. This indicates that precise predictions are difficult, with only 2–4 out of 10 team ranks predicted exactly correctly in most years. Ridge Regression consistently underperforms, suggesting that linear assumptions do not capture the complexity of team ranking dynamics.
#
# Despite these limitations, the models do outperform a random baseline (around 14–17% for a 6–7 team conference) and can still provide useful trend insights. Even if exact ranks are not always correct, predictions close to the true rank can help identify teams likely to improve or decline.
#
# In conclusion, while the models show some promise in identifying general ranking patterns, variability across years highlights the difficulty of predicting exact team ranks.
